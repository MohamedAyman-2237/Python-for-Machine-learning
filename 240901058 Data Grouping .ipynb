# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAyman-2237/Python-for-Machine-learning/blob/main/240901058%20Data%20Grouping%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aim:
#
# To perform Data Grouping functions
#
# Description:
# 1. Create a DataFrame.
# 2. Implement the following Data Grouping functions.
# - Mean
# - Sum
# - First
# - Last
# - Count
# - Size

# %%
import pandas as pd
df= pd.DataFrame({'Animal': ['Tiger', 'Lion', 'Cheetah','Deer'],
'Max speed': ['130', '110', '180', '160']})
print(df)
# Out:
#     Animal Max speed
# 0    Tiger       130
# 1     Lion       110
# 2  Cheetah       180
# 3     Deer       160

# %%
b=df.groupby(['Animal']).sum()
print("\nOriginal DataFrame\n",df)
print("\nGroup by through Column using sum\n",b)
# Out:
# Original DataFrame
#      Animal Max speed
# 0    Tiger       130
# 1     Lion       110
# 2  Cheetah       180
# 3     Deer       160
#
# Group by through Column using sum
#          Max speed
# Animal
# Cheetah       180
# Deer          160
# Lion          110
# Tiger         130

# %%
c=df.groupby(['Animal']).count()
print("\nOriginal DataFrame\n",df)
print("\nGroup by through Column using count\n",c)
# Out:
# Original DataFrame
#      Animal Max speed
# 0    Tiger       130
# 1     Lion       110
# 2  Cheetah       180
# 3     Deer       160
#
# Group by through Column using count
#           Max speed
# Animal
# Cheetah          1
# Deer             1
# Lion             1
# Tiger            1

# %%
d=df.groupby(['Animal']).first()
print("\nOriginal DataFrame\n",df)
print("\nGroup by through Column using first\n",d)
# Out:
# Original DataFrame
#      Animal Max speed
# 0    Tiger       130
# 1     Lion       110
# 2  Cheetah       180
# 3     Deer       160
#
# Group by through Column using first
#          Max speed
# Animal
# Cheetah       180
# Deer          160
# Lion          110
# Tiger         130

# %%
e=df.groupby(['Animal']).count()
print("\nOriginal DataFrame\n", df)
print("\nGroup by through Column using count\n",e)
# Out:
# Original DataFrame
#      Animal Max speed
# 0    Tiger       130
# 1     Lion       110
# 2  Cheetah       180
# 3     Deer       160
#
# Group by through Column using count
#           Max speed
# Animal
# Cheetah          1
# Deer             1
# Lion             1
# Tiger            1

# %%
f=df.groupby(['Animal']).size()
print("\nOriginal DataFrame\n",df)
print("\nGroup by through Column using size\n",f)
# Out:
# Original DataFrame
#      Animal Max speed
# 0    Tiger       130
# 1     Lion       110
# 2  Cheetah       180
# 3     Deer       160
#
# Group by through Column using size
#  Animal
# Cheetah    1
# Deer       1
# Lion       1
# Tiger      1
# dtype: int64
