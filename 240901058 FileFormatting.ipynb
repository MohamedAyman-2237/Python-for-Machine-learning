# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAyman-2237/Python-for-Machine-learning/blob/main/240901058%20FileFormatting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aim:**
#   TO understand file handling operations in Python by writing,reading and appending text data using different file modes,and to learn the basic usgae of JSON loads() and dumps() functions for data scrialization and descrialization.
#
# **Description:**
#
# 1. Open a text file in Write mode
#
# 2. Write the text content and close the file
# 3. Open thesame text file in Read mode
# 4. Read the file content through readline function and close the file
# 5. Open the same file in Append mode
# 6. Add few more text and close the file
# 7. Open the same text file in Read mode
# 8. Read the entire file content through read function and close the file
# 9. Use basic JSON loads and dumps functions
#
# **NOTE**: JSON (JavaScript Object Notation) is a lightweight ,text-based data format used to store and exchange data between systems. It represents data in key-value pairs and is easyeasy for

# %%
#Open a text file in 'Write' mode to write the given lines
f=open("textfile.txt", 'w')
f.write("first line\n")
f.write("Second line\n")
f.write("third line\n")
f.close()
#Open a text file in 'Read' mode to read and print the available lines - readline function
k=open("textfile.txt", 'r')
print(k.readline())
print(k.readline())
print(k.readline())
k.close()
# Out:
# first line
#
# Second line
#
# third line

# %%
#Open a text file in'Append' mode toadd/append new line inputs
m=open("textfile.txt",'a')
m.write("fourth line\n")
m.write("fifth line\n")
m.close()

#Open a text file in 'Read' mode to read and print the available full text-read function
p=open("textfile.txt",'r')
print(p.read())
p.close()
# Out:
# first line
# Second line
# third line
# fourth line
# fifth line

# %%
with open("textfile.txt",'r') as file:
    lines=file.readlines()
    print(lines)
# Out:
# ['first line\n', 'Second line\n', 'third line\n', 'fourth line\n', 'fifth line\n']

# %%
import json
#JSON string
x='{"name":"John","age":30,"city":"New York"}'
#Parse x
y=json.loads(x)
print(y["age"])
# Out:
# 30

# %%
#python dictionary
data={
    "name":"John",
    "age":30,
    "city":"New York"
}

#Convert Python dictionary to JSON string
json_data=json.dumps(data)
print(json_data)
# Out:
# {"name": "John", "age": 30, "city": "New York"}
