# %% [markdown]
# <a href="https://colab.research.google.com/github/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aim:**
#
# To implement and check Time Series functions in Python
#
# **Description:**
#
# 1. Get today's, previous day and next day dates
# 2. Display the data format from the raw data
# 3. Replacing the day/month/year with replace function
# 4. Display day/month/year from current date

# %% [markdown]
# ### 1. Get current date and time using `datetime.now()`

# %%
import datetime

a = datetime.datetime.now()
print("today-now function: ", a)

# %% [markdown]
# ### 2. Get today's date using `datetime.today()`

# %%
today = datetime.datetime.today()
print("today: ", today)

# %% [markdown]
# ### 3. Get tomorrow's date (3 days ahead)

# %%
tomorrow = today + datetime.timedelta(days=3)
print("tomorrow:", tomorrow)

# %% [markdown]
# ### 4. Get yesterday's date (2 days behind)

# %%
yesterday = today - datetime.timedelta(days=2)
print("yesterday: ", yesterday)

# %% [markdown]
# ### 5. Display a specific raw date format using `datetime()`

# %%
a = datetime.datetime.now()
b = datetime.datetime(2020, 6, 8, 23, 10, 25, 404040)
print("date format [2020,6,8,23,10,25,404040):", b)

# %% [markdown]
# ### 6. Replace day in a date using `.replace()`

# %%
from datetime import date

d = date(2024, 12, 31)
print("Replacing date", d, d.replace(day=15))

# %% [markdown]
# ### 7. Display day and month using `.ctime()`

# %%
t = date(2004, 4, 17)
d = date(2004, 4, 17).ctime()
print("Day and Month:", t, d)

# %% [markdown]
# ### 8. Extract year, month and day from today's date

# %%
today = date.today()
print("Today:", today)
print("Current year:", today.year)
print("Current month:", today.month)
print("Current day:", today.day)
