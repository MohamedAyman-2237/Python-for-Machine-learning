# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAyman-2237/Python-for-Machine-learning/blob/main/240901058%20Data%20cleaning%20and%20preparation%20DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aim:
#
# To study and implement different techniques for handling missing values in a Pandas
# DataFrame using functions such as dropna(), fillna(), replace(), isnull(), notnull(), and
# forward/backward filling methods, in order to improve data quality and reliability for data
# analysis and machine learning applications.
#
# Description:
#
# Missing data is always a problem in real life scenarios. Areas like machine learning and data
# mining face severe issues in the accuracy of their model predictions because of poor quality of
# data caused by missing values. In these areas, missing value treatment is a major point of focus
# to make their models more accurate and valid.
# Handling Missing Values (Say NA Or Nan) Using Pandas - DataFrame.
# 1. Drop missing values using dropna() function
# 2. Fill the missing values using fillna() function
# 3. Replacing missing values using replace() with a scalar value is equivalent behavior of the
# fillna() function.
# 4. Through isnull() and notnull() functions, we can identify the NaN as Boolean result.
# 5. Fill the missing values from Forward and Backward values through pad/ffill and bfill/backfill
# functions respectively.

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.634774  0.848267 -2.447153
# b       NaN       NaN       NaN
# c -1.128089  0.795600 -0.082924
# d  0.448205  1.183718  0.895527
# e       NaN       NaN       NaN
# f -1.282902 -1.348297 -0.494990
#
#
# Dropped DataFrame
#          one       two     three
# a -0.634774  0.848267 -2.447153
# c -1.128089  0.795600 -0.082924
# d  0.448205  1.183718  0.895527
# f -1.282902 -1.348297 -0.494990

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one      two     three
# a -1.106030 -0.26638  0.311953
# b       NaN      NaN       NaN
# c  0.582603 -0.75271  0.085563
#
#
# NaN replaced with '0':
#
#         one      two     three
# a -1.106030 -0.26638  0.311953
# b  0.000000  0.00000  0.000000
# c  0.582603 -0.75271  0.085563

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  1.697172  0.317412  0.435078
# b       NaN       NaN       NaN
# c -0.403418 -0.207326  0.530469
# d  0.701010 -0.226043 -0.030763
# e       NaN       NaN       NaN
# f -0.201610 -0.496998  0.789434
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.134231  0.612000  2.378397
# b       NaN       NaN       NaN
# c -0.596169  0.417363  0.906758
# d -0.506186 -1.054870 -0.325270
# e       NaN       NaN       NaN
# f -1.261194  1.059772  0.576936
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.134231  0.612000  2.378397
# b -0.596169  0.417363  0.906758
# c -0.596169  0.417363  0.906758
# d -0.506186 -1.054870 -0.325270
# e -1.261194  1.059772  0.576936
# f -1.261194  1.059772  0.576936
# /tmp/ipykernel_13946/4216389697.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
