# %% [markdown]
# <a href="https://colab.research.google.com/github/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aim:
#
# To implement and check Time Series functions in Python
#
# Description:
#
# 1. Different date strings formats are checked

# %%
import datetime
cd=datetime.datetime.now()
print(cd)
# Out:
# 2026-04-20 10:08:04.180368

# %%
res=cd.strftime("%y")
print("Two-digit year:", res)
# Out:
# Two-digit year: 26

# %%
res1=cd.strftime("%Y")
print("Four-digit year:", res1)
# Out:
# Four-digit year: 2026

# %%
res=cd.strftime("%m")
print("Two-digit month [01, 12]:",res)
# Out:
# Two-digit month [01, 12]: 04

# %%
res=cd.strftime("%b")
print("Short version of month", res)
# Out:
# Short version of month Apr

# %%
res=cd.strftime("%B")
print("Full name of month:",res)
# Out:
# Full name of month: April

# %%
res=cd.strftime("%j")
print("Days of the year:", res)
# Out:
# Days of the year: 110

# %%
res=cd.strftime("%D")
print("Shortcut for %m/%d/%y (e.g., 04/18/12):", res)
# Out:
# Shortcut for %m/%d/%y (e.g., 04/18/12): 04/20/26

# %%
res=cd.strftime("%d")
print("Two-digit day [01, 31]:", res)
# Out:
# Two-digit day [01, 31]: 20

# %%
res=cd.strftime("%a")
print("Short version of day", res)
# Out:
# Short version of day Mon

# %%
res=cd.strftime("%A")
print("Full name of a day:", res)
# Out:
# Full name of a day: Monday

# %%
res=cd.strftime("%H")
print("Hour (24-hour clock) [00, 23]:",res)
# Out:
# Hour (24-hour clock) [00, 23]: 10

# %%
res=cd.strftime("%I")
print("Hour (12-hour clock) [01, 12]",res)
# Out:
# Hour (12-hour clock) [01, 12] 10

# %%
res=cd.strftime("%M")
print("Two-digit minute [00, 59]:", res)
# Out:
# Two-digit minute [00, 59]: 08

# %%
res=cd.strftime("%S")
print("Second (00, 61] (seconds 60, 61 account for leap seconds):",res)
# Out:
# Second (00, 61] (seconds 60, 61 account for leap seconds): 04

# %%
res=cd.strftime("%F")
print("Shortcut for %Y-%m-%d (eg, 2012-4-18):",res)
# Out:
# Shortcut for %Y-%m-%d (eg, 2012-4-18): 2026-04-20

# %%
res=cd.strftime("%f")
print("Microsecond as an integer, zero-padded (from 000000 to 999999);", res)
# Out:
# Microsecond as an integer, zero-padded (from 000000 to 999999); 180368

# %%
res=cd.strftime("%p")
print("Locale equivalent of AM or PM:", res)
# Out:
# Locale equivalent of AM or PM: AM

# %%
res=cd.strftime("%x")
print("Locale-appropriate formatted date (eg, in the United States, May 1, 2012 yields '05/01/2012)", res)
# Out:
# Locale-appropriate formatted date (eg, in the United States, May 1, 2012 yields '05/01/2012) 04/20/26

# %%
res=cd.strftime("%X")
print("Locale-appropriate time (e.g., '04:24:12 PM'):",res)
# Out:
# Locale-appropriate time (e.g., '04:24:12 PM'): 10:08:04
