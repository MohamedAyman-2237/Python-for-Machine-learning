# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAyman-2237/Python-for-Machine-learning/blob/main/240901058%20Data%20Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# Aim:
# To import Data Visualization packages and do the basic functions.
# Description:
# 1. Get the X-axis and Y-axis points through Numpy array and plot the line.
# 2. Plot the points without line using the following ‘marker’ options.
# Marker options:
#
#     ‘O’ – circle
#
#     ‘*’ – Star
#
#     ‘.’ – point
#
#     ‘d’ – Diamond (thin)
#
#     ‘D’ – Diamond
#
#     ‘s’ – Square
#
#     ‘p’ – plus
#
#     ‘+’ – plus
#
#     ‘H’ or ‘h’ – Hexagon
#
#     ‘p’ – pentagon
#
#     ‘v’ – Triangle down
#
#     ‘ᴧ’ – Triangle up
#
#     ‘<’ – Triangle left
#
#     ‘>’ – Triangle right
#
# 3. Multiple points options also can be plotted
# 4. Using default X-axis value by specifying only Y-axis value, we can plot points.

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,10])
ypoints=np.array([20,100])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# ...
# None

# %%
x=np.array([0,5])
y=np.array([0,25])
print(plt.plot(x,y,marker='p'))
print(plt.show())
# Out:
# ...
# None

# %%
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# ...
# None

# %%
ypoints = np.array([5,7,1,0,3])
print(plt.plot(ypoints))
print(plt.show())
# Out:
# ...
# None

# %%
xpoints= np.array([3,8,1,4,9])
ypoints = np.array([5,7,1,0,3])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# ...
# None
