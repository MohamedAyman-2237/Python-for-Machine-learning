# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAyman-2237/Python-for-Machine-learning/blob/main/240901058%20Load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **Aim:**
# To read Excel/CSV/Text files and extract the relevant information
#
# #### **Description:**
# 1. Read and display the excel file data
# 2. Through DataFrame get the details of column headings
# 3. Through DataFrame get the details of the shape of Excel table
# 4. Through DataFrame get the particular columnb values
# 5. Through DataFrame extract/slice the Excel table values
# 6. Through DataFrame get the particular row values
# 7. Through DataFrame make an average of particular column values
#
# ---
# #### Programs:

# %%
import numpy as np
import pandas as pd

d = pd.read_csv("/content/employees details.csv")
print(d)
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
print(d.head())
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
#
#                          E Mail     Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 4  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#   Mother's Maiden Name  Salary
# 0                Lewis  168251
# 1                Perry   51063
# 2               Taylor   50155
# ...

# %%
print(d.tail())
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                       E Mail   Father's Name      Mother's Name  \
# 95     jose.hill@hotmail.com     Carlos Hill          Anna Hill
# 96   harold.nelson@gmail.com  Richard Nelson      Pamela Nelson
# 97     nicole.ward@yahoo.com      Ralph Ward         Julia Ward
# 98  theresa.murphy@gmail.com   George Murphy  Jacqueline Murphy
# 99   tammy.young@comcast.net    Andrew Young       Brenda Young
#
#    Mother's Maiden Name  Salary
# 95                Hayes  129774
# 96                Smith  156194
# 97                  Lee   95673
# 98             Peterson   51015
# ...

# %%
print(d.nunique())
# Out:
# Emp ID                  100
# Name Prefix               7
# First Name               79
# Middle Initial           25
# Last Name                68
# Gender                    2
# E Mail                  100
# Father's Name           100
# Mother's Name           100
# Mother's Maiden Name     61
# Salary                  100
# dtype: int64

# %%
#Get the column heading
df = pd.DataFrame(d)
print("Columns", df.columns)
# Out:
# Columns Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Salary'],
#       dtype='object')

# %%
#Get the shape - (no. of rows, no. of columns)
print(df.shape)
# Out:
# (100, 11)

# %%
print("ID:", df["Emp ID"])
# Out:
# ID:
#
#   0     677509
# 1     940761
# 2     428945
# 3     408351
# 4     193819
#        ...
# 95    639892
# 96    704709
# 97    461593
# 98    392491
# 99    495141
# Name: Emp ID, Length: 100, dtype: int64

# %%
#Extract/slice the table values - [including this row, excluding this row]
print(df[5:8])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
#
#                    E Mail  Father's Name     Mother's Name  \
# 5  patrick.bailey@aol.com   Ralph Bailey      Laura Bailey
# 6      nancy.baker@bp.com    Scott Baker        Judy Baker
# 7  carol.murphy@gmail.com  Eugene Murphy  Katherine Murphy
#
#   Mother's Maiden Name  Salary
# 5            Henderson   72305
# 6               Thomas   98189
# 7             Peterson   60918

# %%
#Get the particular row values - through row number identification
print("Output:\n\nParticular person details\n", df.loc[10])
# Out:
# Output:
#
# Particular person details
#  Emp ID                                  231469
# Name Prefix                                Mr.
# First Name                               Ralph
# Middle Initial                               L
# Last Name                               Flores
# Gender                                       M
# E Mail                  ralph.flores@yahoo.com
# Father's Name                     Terry Flores
# Mother's Name                  Michelle Flores
# Mother's Maiden Name                     Moore
# Salary                                  118457
# Name: 10, dtype: object

# %%
#Instead of company employ dataset we can use students mark list dataset. If the average of total mark is required use this code
#Make an average of total marks
df = d['Salary']/100
print("\nMake an average of total marks:\n", df)
# Out:
# Make an average of total marks:
#  0     1682.51
# 1      510.63
# 2      501.55
# 3     1802.94
# 4     1176.42
#        ...
# 95    1297.74
# 96    1561.94
# 97     956.73
# 98     510.15
# 99     936.50
# Name: Salary, Length: 100, dtype: float64
